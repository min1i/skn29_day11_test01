# %% [markdown]
# # 공공 API 활용
# https://www.data.go.kr/data/15059401/openapi.do

# %%
import requests
import xml.etree.ElementTree as ET
import os
from dotenv import load_dotenv
load_dotenv()

service_key = os.getenv('PUBLIC_SERVICE_KEY')
url = 'https://apis.data.go.kr/B553881/newRegistlnfoService_02/getnewRegistlnfoService02'


params = {
    'serviceKey' : service_key,
    'registYy' : '2017',
    'registMt' : '09',
    'vhctyAsortCode' : 1,
    'registGrcCode' : 1
}

response = requests.get(url, params=params)
print(f'코드 : {response.status_code}')
print(response.text) # 문자열 xml 구조

root = ET.fromstring(response.text)

for child in root.find('header'): # Element 객체
    print(child.tag, child.text)

for child in root.find('body'): # Element 객체
    print(child.tag, child.text)

print(root.findtext('body/dtaCo'))
# Out:
# 코드 : 200
# <response><header><resultCode>00</resultCode><resultMsg>NORMAL_CODE</resultMsg></header><body><dtaCo>23212</dtaCo></body></response>
# resultCode 00
# resultMsg NORMAL_CODE
# dtaCo 23212
# 23212

# %%
# %pip install xmltodict

# %%
import xmltodict

data = xmltodict.parse(response.text)
print(data)

data.get('response').get('body').get('dtaCo')
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL_CODE'}, 'body': {'dtaCo': '23212'}}}
# '23212'
